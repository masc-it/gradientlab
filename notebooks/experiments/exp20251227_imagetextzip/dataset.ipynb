# %%
from datasets import load_from_disk

# %%
ds = load_from_disk("/Users/mascit/projects/gradientlab/data.tmp/dataset_min_coin_10k")

# %%
ds_train = ds["train"]

# %%
print(ds_train[34]["text"])
# Out:
# {
#   "coins": [
#     2,
#     5,
#     8,
#     9,
#     11,
#     25,
#     26,
#     27,
#     28,
#     29,
#     30,
#     35,
#     37,
#     38,
#     40,
#     41,
#     44,
#     48,
#     49
#   ],
#   "amount": 713,
#   "solution": [
#     48,
#     48,
#     48,
#     48,
#     48,
#     48,
#     48,
#     48,
#     48,
#     48,
#     48,
#     48,
#     48,
#     48,
#     41
#   ],
#   "answer": 15
# }

# %%
lenghts = [len(ds_train[i]["text"]) for i in range(len(ds_train))]

# %%
max(lenghts)
# Out:
# 3307
